# %% [markdown]
# Attempt at building light curves for the PAL5 data

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.io import ascii
from astropy.table import Table
from astropy.coordinates import SkyCoord
from astropy.coordinates import match_coordinates_sky
from astropy import wcs
from astropy import units as u
from astropy.time import Time

# %%
image_1 = 'PAL5_data/PAL5__e1/PAL5__e1_3p6um.fits'
image_2 = 'PAL5_data/PAL5__e2/PAL5__e2_3p6um.fits'
image_3 = 'PAL5_data/PAL5__e3/PAL5__e3_3p6um.fits'
image_4 = 'PAL5_data/PAL5__e4/PAL5__e4_3p6um.fits'
image_5 = 'PAL5_data/PAL5__e5/PAL5__e5_3p6um.fits'
image_6 = 'PAL5_data/PAL5__e6/PAL5__e6_3p6um.fits'
image_7 = 'PAL5_data/PAL5__e7/PAL5__e7_3p6um.fits'
image_8 = 'PAL5_data/PAL5__e8/PAL5__e8_3p6um.fits'
image_9 = 'PAL5_data/PAL5__e9/PAL5__e9_3p6um.fits'
image_10 = 'PAL5_data/PAL5__e10/PAL5__e10_3p6um.fits'
image_11 = 'PAL5_data/PAL5__e11/PAL5__e11_3p6um.fits'
image_12 = 'PAL5_data/PAL5__e12/PAL5__e12_3p6um.fits'

def Header_detail(image):
    global header, time, data
    with fits.open(image) as hdr:
        header = hdr[0].header
        time = Time(header['DATE_OBS'])
        data = fits.getdata(image, ext = 0)
    return header, time, data

time_stamp = []

Header_detail(image_1)
header1 = header
time1 = time
data1 = data
delta_time = time1 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_2)
header2 = header
time2 = time
data2 = data
delta_time = time2 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_3)
header3 = header
time3 = time
data3 = data
delta_time = time3 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_4)
header4 = header
time4 = time
data4 = data
delta_time = time4 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_5)
header5 = header
time5 = time
data5 = data
delta_time = time5 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_6)
header6 = header
time6 = time
data6 = data
delta_time = time6 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_7)
header7 = header
time7 = time
data7 = data
delta_time = time7 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_8)
header8 = header
time8 = time
data8 = data
delta_time = time8 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_9)
header9 = header
time9 = time
data9 = data
delta_time = time9 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_10)
header10 = header
time10 = time
data10 = data
delta_time = time10 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_11)
header11 = header
time11 = time
data11 = data
delta_time = time11 - time1
time_stamp.append(delta_time.sec)

Header_detail(image_12)
header12 = header
time12 = time
data12 = data
delta_time = time12 - time1
time_stamp.append(delta_time.sec)

print(time_stamp)

#hdr_1_list = fits.open(image_1)
#hdr_1 = hdr_1_list[0].header
#time1 = Time(hdr_1['DATE_OBS'])
#print(time1)
#hdr_1_list.close()
#data_1 = fits.getdata(image_1, ext = 0)

#hdr_2_list = fits.open(image_2)
#hdr_2 = hdr_2_list[0].header
#time2 = Time(hdr_2['DATE_OBS'])
#print(time2)
#hdr_2_list.close()
#data_2 = fits.getdata(image_2, ext = 0)

#timedelta = time2 - time1
#print(timedelta.sec)
# Out:
# [0.0, 6101.122000000001, 10699.064999999997, 16165.991999999998, 21512.525000000005, 27298.826000000005, 31746.773999999998, 37331.673, 42701.054000000004, 47401.992999999995, 52657.174, 58685.706000000006]

# %%
file_1 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch1_3p6um.txt'
file_2 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch2_3p6um.txt'
file_3 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch3_3p6um.txt'
file_4 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch4_3p6um.txt'
file_5 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch5_3p6um.txt'
file_6 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch6_3p6um.txt'
file_7 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch7_3p6um.txt'
file_8 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch8_3p6um.txt'
file_9 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch9_3p6um.txt'
file_10 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch10_3p6um.txt'
file_11 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch11_3p6um.txt'
file_12 = r'C:/Users/lukeb/Documents/MPhys_RRLs/output_files/aperphot_epoch12_3p6um.txt'

f1 = ascii.read(file_1, delimiter = ',')
f2 = ascii.read(file_2, delimiter = ',')
f3 = ascii.read(file_3, delimiter = ',')
f4 = ascii.read(file_4, delimiter = ',')
f5 = ascii.read(file_5, delimiter = ',')
f6 = ascii.read(file_6, delimiter = ',')
f7 = ascii.read(file_7, delimiter = ',')
f8 = ascii.read(file_8, delimiter = ',')
f9 = ascii.read(file_9, delimiter = ',')
f10 = ascii.read(file_10, delimiter = ',')
f11 = ascii.read(file_11, delimiter = ',')
f12 = ascii.read(file_12, delimiter = ',')

# %%
x_1, y1 = f1['xcenter'], f1['ycenter']
x_2, y2 = f2['xcenter'], f2['ycenter']
x_3, y3 = f3['xcenter'], f3['ycenter']
x_4, y4 = f4['xcenter'], f4['ycenter']
x_5, y5 = f5['xcenter'], f5['ycenter']
x_6, y6 = f6['xcenter'], f6['ycenter']
x_7, y7 = f7['xcenter'], f7['ycenter']
x_8, y8 = f8['xcenter'], f8['ycenter']
x_9, y9 = f9['xcenter'], f9['ycenter']
x_10, y10 = f10['xcenter'], f10['ycenter']
x_11, y11 = f11['xcenter'], f11['ycenter']
x_12, y12 = f12['xcenter'], f12['ycenter']

w1 = wcs.WCS(header1)
w2 = wcs.WCS(header2)
w3 = wcs.WCS(header3)
w4 = wcs.WCS(header4)
w5 = wcs.WCS(header5)
w6 = wcs.WCS(header6)
w7 = wcs.WCS(header7)
w8 = wcs.WCS(header8)
w9 = wcs.WCS(header9)
w10 = wcs.WCS(header10)
w11 = wcs.WCS(header11)
w12 = wcs.WCS(header12)

coord_1 = np.transpose((x_1, y_1))
coord_2 = np.transpose((x_2, y_2))
coord_3 = np.transpose((x_3, y_3))
coord_4 = np.transpose((x_4, y_4))
coord_5 = np.transpose((x_5, y_5))
coord_6 = np.transpose((x_6, y_6))
coord_7 = np.transpose((x_7, y_7))
coord_8 = np.transpose((x_8, y_8))
coord_9 = np.transpose((x_9, y_9))
coord_10 = np.transpose((x_10, y_10))
coord_11 = np.transpose((x_11, y_11))
coord_12 = np.transpose((x_12, y_12))
world_1 = w1.wcs_pix2world(coord_1, 0)
world_2 = w2.wcs_pix2world(coord_2, 0)
world_3 = w3.wcs_pix2world(coord_3, 0)
world_4 = w4.wcs_pix2world(coord_4, 0)
world_5 = w5.wcs_pix2world(coord_5, 0)
world_6 = w6.wcs_pix2world(coord_6, 0)
world_7 = w7.wcs_pix2world(coord_7, 0)
world_8 = w8.wcs_pix2world(coord_8, 0)
world_9 = w9.wcs_pix2world(coord_9, 0)
world_10 = w10.wcs_pix2world(coord_10, 0)
world_11 = w11.wcs_pix2world(coord_11, 0)
world_12 = w12.wcs_pix2world(coord_12, 0)
